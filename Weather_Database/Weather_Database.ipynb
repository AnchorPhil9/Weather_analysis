# %%
# Import the dependencies. 
#6.1.4
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Create a set of random latitude and longitude combinations, as per 6.1.4 (2021).
# This time, we'll make 2000 random latitudes and longitude for the Module 6 Challenge (2021).
lats = np.random.uniform(low=-90.000, high=90.000, size=2000) 
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000) 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
# 6.1.4
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
# 6.1.5
from citipy import citipy
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Dependencies defined in 6.2.3 (2021).
import requests
from config import weather_api_key
# We will also import the datetime module as we did in 6.2.5 (2021) and 6.2.6 (2021).
from datetime import datetime
# Build query URL that specifies current temperature results in Fahrenheit.
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key + "&units=imperial"

# %%
# Taking a look at our list of cities
cities
# Out:
# ['san cristobal',
#  'san quintin',
#  'ruatoria',
#  'qaanaaq',
#  'rikitea',
#  'vila do maio',
#  'punta arenas',
#  'sorland',
#  'bethel',
#  'skagastrond',
#  'san patricio',
#  'eureka',
#  'busselton',
#  'atuona',
#  'tuktoyaktuk',
#  'hermanus',
#  'flinders',
#  'kapaa',
#  'khilok',
#  'petropavlovsk-kamchatskiy',
#  'bubaque',
#  'karpogory',
#  'vaini',
#  'vila',
#  'east london',
#  'taolanaro',
#  'polson',
#  'marfino',
#  'dunedin',
#  'starkville',
#  'lebu',
#  'butaritari',
#  'port alfred',
#  'dikson',
#  'yeppoon',
#  'port elizabeth',
#  'arraial do cabo',
#  'rungata',
#  'bathsheba',
#  'guarapari',
#  'tasiilaq',
#  'kodiak',
#  'minot',
#  'pindi bhattian',
#  'zhangye',
#  'mataura',
#  'mogadishu',
#  'broken hill',
#  'mahebourg',
#  'lata',
#  'hobart',
#  'bredasdorp',
#  'looc',
#  'wampusirpi',
#  'barentsburg',
#  'guantanamo',
#  'sinnamary',
#  'klaksvik',
#  'albany',
#  'tiksi',
#  'saint-augustin',
#  'melioratorov',
#  'san carlos de bariloche',
#  'jamestown',
#  'ushuaia',
#  'novotroitskaya',
#  'muros',
#  'esso',
#  'la ronge',
#  'batangafo',
#  'nikolskoye',
#  'mehamn',
#  'medina del campo',
#  'kindu',
#  'sorong',
#  'bhadrachalam',
#  'rawannawi',
#  'tashla',
#  'sept-iles',
#  'carnarvon',
#  'tougue',
#  'chor',
#  'chokurdakh',
#  'saint-philippe',
#  'crab hill',
#  'gornozavodsk',
#  'odienne',
#  'tsihombe',
#  'chupa',
#  'cherskiy',
#  'saskylakh',
#  'puerto ayora',
#  'anadyr',
#  'ulaanbaatar',
#  'tasbuget',
#  'gogrial',
#  'new norfolk',
#  'bahia honda',
#  'conakry',
#  'castro',
#  'micco',
#  'narsaq',
#  'cabo san lucas',
#  'grand gaube',
#  'lavrentiya',
#  'mozarlandia',
#  'attawapiskat',
#  'san policarpo',
#  'shiyan',
#  'khatanga',
#  'lasa',
#  'kaitangata',
#  'upernavik',
#  'cape town',
#  'georgetown',
#  'cuenca',
#  'kurumkan',
#  'marsh harbour',
#  'betare oya',
#  'tuatapere',
#  'nioro',
#  'daru',
#  'thompson',
#  'havoysund',
#  'berlevag',
#  'isla vista',
#  'geraldton',
#  'suao',
#  'phan rang',
#  'victoria',
#  'pevek',
#  'tura',
#  'kruisfontein',
#  'longyearbyen',
#  'ostrovnoy',
#  'illoqqortoormiut',
#  'salmon creek',
#  'fortuna',
#  'suileng',
#  'barrow',
#  'phayao',
#  'hilo',
#  'souillac',
#  'eresos',
#  'nantucket',
#  'bluff',
#  'nemuro',
#  'aflu',
#  'eyl',
#  'laguna',
#  'viedma',
#  'esperance',
#  'kavaratti',
#  'ginir',
#  'kasongo-lunda',
#  'inuvik',
#  'nhulunbuy',
#  'amderma',
#  'gat',
#  'mys shmidta',
#  'krasnyy chikoy',
#  'hasaki',
#  'hithadhoo',
#  'do gonbadan',
#  'shingu',
#  'ulkan',
#  'burica',
#  'airai',
#  'yulara',
#  'mangrol',
#  'salalah',
#  'hinatuan',
#  'belushya guba',
#  'kavieng',
#  'samusu',
#  'olavarria',
#  'karasjok',
#  'noumea',
#  'beaumont',
#  'nouadhibou',
#  'rach gia',
#  'seoul',
#  'talnakh',
#  'dubrovka',
#  'fort nelson',
#  'constitucion',
#  'warqla',
#  'honningsvag',
#  'omboue',
#  'solovetskiy',
#  'sitka',
#  'roma',
#  'bambanglipuro',
#  'chenzhou',
#  'labateca',
#  'benguela',
#  'atar',
#  'sao filipe',
#  'avarua',
#  'yellowknife',
#  'chernenko',
#  'bengkulu',
#  'sardarpur',
#  'teeli',
#  'rosario',
#  'vidim',
#  'souris',
#  'severo-kurilsk',
#  'chuy',
#  'tecoanapa',
#  'mar del plata',
#  'zapresic',
#  'riyadh',
#  'norman wells',
#  'berezovyy',
#  'trincomalee',
#  'malwan',
#  'pucallpa',
#  'lamar',
#  'kempele',
#  'rodrigues alves',
#  'rocha',
#  'damavand',
#  'hambantota',
#  'shenzhen',
#  'paamiut',
#  'nosy varika',
#  'ponta do sol',
#  'clyde river',
#  'katsuura',
#  'sao joao da barra',
#  'panama city',
#  'mato verde',
#  'kaniama',
#  'pierre',
#  'carutapera',
#  'abu samrah',
#  'ripon',
#  'dwarka',
#  'margate',
#  'vredendal',
#  'leiyang',
#  'minsk',
#  'izumo',
#  'abha',
#  'saint george',
#  'statesboro',
#  'tessalit',
#  'phan thiet',
#  'wazzan',
#  'hovd',
#  'togur',
#  'ancud',
#  'korla',
#  'xudat',
#  'te anau',
#  'umzimvubu',
#  'quiruvilca',
#  'brae',
#  'springdale',
#  'karlskrona',
#  'caluquembe',
#  'taksimo',
#  'tonj',
#  'samarai',
#  'marshall',
#  'torbay',
#  'faanui',
#  'huarmey',
#  'impfondo',
#  'borogontsy',
#  'joshimath',
#  'lewistown',
#  'karratha',
#  'chagda',
#  'buraydah',
#  'umm lajj',
#  'spearfish',
#  'mount gambier',
#  'kaeo',
#  'nipawin',
#  'yanagawa',
#  'hobyo',
#  'severnyy',
#  'chapais',
#  'itoman',
#  'minab',
#  'mengyin',
#  'houma',
#  'mitu',
#  'caruray',
#  'leh',
#  'mendahara',
#  'wattens',
#  'galesong',
#  'swan river',
#  'rantepao',
#  'harper',
#  'qaqortoq',
#  'usinsk',
#  'hofn',
#  'pokaran',
#  'peniche',
#  'fukue',
#  'urdzhar',
#  'haines junction',
#  'lorengau',
#  'udachnyy',
#  'bilma',
#  'takestan',
#  'comodoro rivadavia',
#  'ayan',
#  'chernyshevskiy',
#  'grindavik',
#  'vohibinany',
#  'codrington',
#  'labuhan',
#  'fairbanks',
#  'manta',
#  'omsukchan',
#  'saryshagan',
#  'vetluga',
#  'general roca',
#  'belyy yar',
#  'tawkar',
#  'shunyi',
#  'goderich',
#  'thinadhoo',
#  'nurota',
#  'vaitupu',
#  'leningradskiy',
#  'medea',
#  'lagoa',
#  'bima',
#  'yefimovskiy',
#  'quatre cocos',
#  'srednekolymsk',
#  'ribeira grande',
#  'phultala',
#  'grand river south east',
#  'charlestown',
#  'ijaki',
#  'tezu',
#  'aviles',
#  'sunrise manor',
#  'aksu',
#  'bambous virieux',
#  'coquimbo',
#  'praia da vitoria',
#  'nanortalik',
#  'boende',
#  'batticaloa',
#  'asosa',
#  'surman',
#  'yomitan',
#  'lesogorsk',
#  'dandong',
#  'gamba',
#  'namie',
#  'fort saint john',
#  'fort smith',
#  'port macquarie',
#  'san pedro',
#  'cidreira',
#  'mabaruma',
#  'sentyabrskiy',
#  'vao',
#  'barra patuca',
#  'djambala',
#  'alofi',
#  'panjakent',
#  'marsa matruh',
#  'mecca',
#  'luderitz',
#  'dingle',
#  'urumqi',
#  'husavik',
#  'adjumani',
#  'natal',
#  'beyneu',
#  'bulancak',
#  'aitape',
#  'port hedland',
#  'pacific grove',
#  'tiznit',
#  'canico',
#  'valparaiso',
#  'arona',
#  'vila franca do campo',
#  'touros',
#  'mountain home',
#  'daliao',
#  'kununurra',
#  'acopiara',
#  'cairns',
#  'suihua',
#  'toliary',
#  'hermiston',
#  'itigi',
#  'buala',
#  'qabis',
#  'akdepe',
#  'azul',
#  'torrington',
#  'shelton',
#  'calabozo',
#  'sambava',
#  'zyryanka',
#  'pisco',
#  'tevaitoa',
#  'bani walid',
#  'maarianhamina',
#  'jahrom',
#  'la sarre',
#  'ouahigouya',
#  'ladario',
#  'filingue',
#  'yar-sale',
#  'virginia beach',
#  'mulege',
#  'camopi',
#  'itaituba',
#  'dezful',
#  'aykhal',
#  'rancho palos verdes',
#  'kudahuvadhoo',
#  'luanda',
#  'konevo',
#  'ilulissat',
#  'krasnoarmeysk',
#  'boa vista',
#  'chino valley',
#  'hay river',
#  'san luis',
#  'kuche',
#  'khani',
#  'kismayo',
#  'sigmaringen',
#  'vrangel',
#  'manokwari',
#  'bonga',
#  'shache',
#  'elat',
#  'lubango',
#  'natchitoches',
#  'iracoubo',
#  'sao jose da coroa grande',
#  'palmer',
#  'salinopolis',
#  'val',
#  'amot',
#  'alyangula',
#  'chimbote',
#  'uzhur-4',
#  'pombia',
#  'presidente medici',
#  'tabuk',
#  'chicama',
#  'ituni',
#  'lahij',
#  'nadym',
#  'mattru',
#  'pasni',
#  'acarau',
#  'nanakuli',
#  'riposto',
#  'cagsiay',
#  'djibo',
#  'bereda',
#  'maxixe',
#  'portland',
#  'gambela',
#  'terney',
#  'ngukurr',
#  'tanout',
#  'provideniya',
#  'port lincoln',
#  'olafsvik',
#  'tumannyy',
#  'santa lucia',
#  'port blair',
#  'miri',
#  'sur',
#  'kasongo',
#  'ulladulla',
#  'elmira',
#  'griffith',
#  'petrozavodsk',
#  'susangerd',
#  'vanderhoof',
#  'bridlington',
#  'port hardy',
#  'aljezur',
#  'rockport',
#  'pangody',
#  'marysville',
#  'baykit',
#  'qasigiannguit',
#  'topolobampo',
#  'rosetown',
#  'bontang',
#  'gizo',
#  'myitkyina',
#  'brigantine',
#  'fort-shevchenko',
#  'gorontalo',
#  'jaciara',
#  'mayo',
#  'komsomolskiy',
#  'kenai',
#  'hue',
#  'katherine',
#  'kembe',
#  'de aar',
#  'gannan',
#  'butembo',
#  'korem',
#  'merauke',
#  'masumbwe',
#  'saint anthony',
#  'aklavik',
#  'arica',
#  'kamenskoye',
#  'north bend',
#  'kota tinggi',
#  'salinas',
#  'dibaya',
#  'emerald',
#  'yeniseysk',
#  'kushima',
#  'marzuq',
#  'springbok',
#  'concepcion del oro',
#  'vung tau',
#  'tabiauea',
#  'neiafu',
#  'russell',
#  'karaul',
#  'makakilo city',
#  'galveston',
#  'batagay-alyta',
#  'canutama',
#  'beloha',
#  'namibe',
#  'taltal',
#  'itarema',
#  'el alto',
#  'marawi',
#  'balad',
#  'saldanha',
#  'opuwo',
#  'iqaluit',
#  'siocon',
#  'mutsamudu',
#  'cabedelo',
#  'puerto baquerizo moreno',
#  'dovbysh',
#  'ouadda',
#  'zhoucheng',
#  'manzhouli',
#  'bandarbeyla',
#  'nizhneyansk',
#  'oxilithos',
#  'arman',
#  'qiongshan',
#  'abbeville',
#  'prainha',
#  'lompoc',
#  'haibowan',
#  'teknaf',
#  'dustlik',
#  'nome',
#  'saleaula',
#  'chandrakona',
#  'lethem',
#  'albanel',
#  'ponferrada',
#  'serenje',
#  'richards bay',
#  'tholos',
#  'pabna',
#  'doctor pedro p. pena',
#  'pitimbu',
#  'linxia',
#  'kokopo',
#  'cururupu',
#  'dong hoi',
#  'saint-pierre',
#  'antofagasta',
#  'palabuhanratu',
#  'cayenne',
#  'lazaro cardenas',
#  'kouroussa',
#  'canavieiras',
#  'aksarka',
#  'vardo',
#  'fukumitsu',
#  'sidney',
#  'deputatskiy',
#  'diego de almagro',
#  'ambilobe',
#  'verkhniye kigi',
#  'northam',
#  'iralaya',
#  'polunochnoye',
#  'kemin',
#  'kalmunai',
#  'lagos',
#  'aripuana',
#  'ketchikan',
#  'erseke',
#  'roebourne',
#  'sooke',
#  'vila velha',
#  'plaridel',
#  'katobu',
#  'languyan',
#  'poum',
#  'nishihara',
#  'agadez',
#  'namtsy',
#  'palafrugell',
#  'taoudenni',
#  'langres',
#  'hailey',
#  'chany',
#  'clovis',
#  'qostanay',
#  'zuwarah',
#  'baherden',
#  'prokopyevsk',
#  'shubarshi',
#  'shakiso',
#  'blairmore',
#  'bedford',
#  'madimba',
#  'alihe',
#  'monte azul',
#  'phon',
#  'rawson',
#  'saint albans',
#  'okha',
#  'binzhou',
#  'pauini',
#  'harij',
#  'inderborskiy',
#  'guiyang',
#  'padang',
#  'oistins',
#  'san ignacio',
#  'bukachacha',
#  'hamilton',
#  'bababe',
#  'dickinson',
#  'ixtapa',
#  'hihifo',
#  'charters towers',
#  'new deer',
#  'sistranda',
#  'la libertad',
#  'baruun-urt',
#  'kieta',
#  'dembi dolo',
#  'nelson bay',
#  'san andres',
#  'cravo norte',
#  'yegorlykskaya',
#  'obo',
#  'plouzane',
#  'sola',
#  'sobolevo',
#  'hlubocky',
#  'caravelas',
#  'cascais',
#  'usagara',
#  'jatiroto',
#  'urdoma',
#  'mersing',
#  'ucluelet',
#  'almaznyy',
#  'grand centre',
#  'south venice',
#  'nicolas bravo',
#  'baghdad',
#  'tiarei',
#  'porto santo',
#  'hanna',
#  'wahiawa',
#  'ardeoani',
#  'hualmay',
#  'aquiraz',
#  'abu zabad',
#  'umm kaddadah',
#  'biggar',
#  'matara',
#  'port-gentil',
#  'kucevo',
#  'egvekinot',
#  'okhotsk',
#  'kysyl-syr',
#  'moron',
#  'saquena',
#  'coolum beach',
#  'lichinga',
#  'manoel urbano',
#  'flin flon',
#  'zermatt',
#  'arroio dos ratos',
#  'seydi',
#  'ahmadpur',
#  'albert town',
#  'teguldet',
#  'port keats',
#  'auki',
#  'uruzgan',
#  'moussoro',
#  'moche',
#  'yanam',
#  'isangel',
#  'swellendam',
#  'albury',
#  'lipin bor',
#  'ihosy',
#  'gumdag',
#  'loikaw',
#  'inirida']

# %%
# Consolidating the city weather code from 6.2.6 (2021) into one cell block.
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Instead of datetime info, we will need weather description info
        # per the Module 6 Challenge (2021). But there's a snag.
        # As seen in the JSON data in 6.2.2 (2021), the weather description info is
        # contained inside a list, unlike the rest of the weather data.
        # The list has one element: a dictionary with several values.
        # To access the list's one element, we need to use that list's index number 0
        # in the syntax, as mentioned back in 3.2.5 (2021).
        # Afterwards, we can call on the "description" key for the weather description info.
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san cristobal
# Processing Record 2 of Set 1 | san quintin
# Processing Record 3 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | vila do maio
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | sorland
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | eureka
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | flinders
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | khilok
# Processing Record 20 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 1 | bubaque
# Processing Record 22 of Set 1 | karpogory
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | vila
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | polson
# Processing Record 28 of Set 1 | marfino
# Processing Record 29 of Set 1 | dunedin
# Processing Record 30 of Set 1 | starkville
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | yeppoon
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 1 | bathsheba
# Processing Record 40 of Set 1 | guarapari
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | minot
# Processing Record 44 of Set 1 | pindi bhattian
# Processing Record 45 of Set 1 | zhangye
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | mogadishu
# Processing Record 48 of Set 1 | broken hill
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 50 of Set 1 | lata
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | looc
# Processing Record 4 of Set 2 | wampusirpi
# City not found. Skipping...
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | guantanamo
# Processing Record 7 of Set 2 | sinnamary
# Processing Record 8 of Set 2 | klaksvik
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | saint-augustin
# Processing Record 12 of Set 2 | melioratorov
# Processing Record 13 of Set 2 | san carlos de bariloche
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | novotroitskaya
# Processing Record 17 of Set 2 | muros
# Processing Record 18 of Set 2 | esso
# Processing Record 19 of Set 2 | la ronge
# Processing Record 20 of Set 2 | batangafo
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | mehamn
# Processing Record 23 of Set 2 | medina del campo
# Processing Record 24 of Set 2 | kindu
# Processing Record 25 of Set 2 | sorong
# Processing Record 26 of Set 2 | bhadrachalam
# Processing Record 27 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 2 | tashla
# Processing Record 29 of Set 2 | sept-iles
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | tougue
# Processing Record 32 of Set 2 | chor
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 36 of Set 2 | gornozavodsk
# Processing Record 37 of Set 2 | odienne
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | chupa
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | anadyr
# Processing Record 44 of Set 2 | ulaanbaatar
# Processing Record 45 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 2 | gogrial
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | bahia honda
# Processing Record 49 of Set 2 | conakry
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | micco
# Processing Record 2 of Set 3 | narsaq
# Processing Record 3 of Set 3 | cabo san lucas
# Processing Record 4 of Set 3 | grand gaube
# Processing Record 5 of Set 3 | lavrentiya
# Processing Record 6 of Set 3 | mozarlandia
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | san policarpo
# Processing Record 9 of Set 3 | shiyan
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | lasa
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | cape town
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | cuenca
# Processing Record 17 of Set 3 | kurumkan
# Processing Record 18 of Set 3 | marsh harbour
# Processing Record 19 of Set 3 | betare oya
# Processing Record 20 of Set 3 | tuatapere
# Processing Record 21 of Set 3 | nioro
# Processing Record 22 of Set 3 | daru
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | havoysund
# Processing Record 25 of Set 3 | berlevag
# Processing Record 26 of Set 3 | isla vista
# Processing Record 27 of Set 3 | geraldton
# Processing Record 28 of Set 3 | suao
# City not found. Skipping...
# Processing Record 29 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | pevek
# Processing Record 32 of Set 3 | tura
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | ostrovnoy
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 3 | salmon creek
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | suileng
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | phayao
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | eresos
# Processing Record 45 of Set 3 | nantucket
# Processing Record 46 of Set 3 | bluff
# Processing Record 47 of Set 3 | nemuro
# Processing Record 48 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 3 | eyl
# Processing Record 50 of Set 3 | laguna
# Processing Record 1 of Set 4 | viedma
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | kavaratti
# Processing Record 4 of Set 4 | ginir
# Processing Record 5 of Set 4 | kasongo-lunda
# Processing Record 6 of Set 4 | inuvik
# Processing Record 7 of Set 4 | nhulunbuy
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 4 | gat
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | krasnyy chikoy
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | hithadhoo
# Processing Record 14 of Set 4 | do gonbadan
# Processing Record 15 of Set 4 | shingu
# Processing Record 16 of Set 4 | ulkan
# Processing Record 17 of Set 4 | burica
# City not found. Skipping...
# Processing Record 18 of Set 4 | airai
# Processing Record 19 of Set 4 | yulara
# Processing Record 20 of Set 4 | mangrol
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | hinatuan
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | kavieng
# Processing Record 25 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 4 | olavarria
# Processing Record 27 of Set 4 | karasjok
# Processing Record 28 of Set 4 | noumea
# Processing Record 29 of Set 4 | beaumont
# Processing Record 30 of Set 4 | nouadhibou
# Processing Record 31 of Set 4 | rach gia
# Processing Record 32 of Set 4 | seoul
# Processing Record 33 of Set 4 | talnakh
# Processing Record 34 of Set 4 | dubrovka
# Processing Record 35 of Set 4 | fort nelson
# Processing Record 36 of Set 4 | constitucion
# Processing Record 37 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 4 | honningsvag
# Processing Record 39 of Set 4 | omboue
# Processing Record 40 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | roma
# Processing Record 43 of Set 4 | bambanglipuro
# Processing Record 44 of Set 4 | chenzhou
# Processing Record 45 of Set 4 | labateca
# Processing Record 46 of Set 4 | benguela
# Processing Record 47 of Set 4 | atar
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | avarua
# Processing Record 50 of Set 4 | yellowknife
# Processing Record 1 of Set 5 | chernenko
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | sardarpur
# Processing Record 4 of Set 5 | teeli
# Processing Record 5 of Set 5 | rosario
# Processing Record 6 of Set 5 | vidim
# Processing Record 7 of Set 5 | souris
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | chuy
# Processing Record 10 of Set 5 | tecoanapa
# Processing Record 11 of Set 5 | mar del plata
# Processing Record 12 of Set 5 | zapresic
# Processing Record 13 of Set 5 | riyadh
# Processing Record 14 of Set 5 | norman wells
# Processing Record 15 of Set 5 | berezovyy
# Processing Record 16 of Set 5 | trincomalee
# Processing Record 17 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 5 | pucallpa
# Processing Record 19 of Set 5 | lamar
# Processing Record 20 of Set 5 | kempele
# Processing Record 21 of Set 5 | rodrigues alves
# Processing Record 22 of Set 5 | rocha
# Processing Record 23 of Set 5 | damavand
# Processing Record 24 of Set 5 | hambantota
# Processing Record 25 of Set 5 | shenzhen
# Processing Record 26 of Set 5 | paamiut
# Processing Record 27 of Set 5 | nosy varika
# Processing Record 28 of Set 5 | ponta do sol
# Processing Record 29 of Set 5 | clyde river
# Processing Record 30 of Set 5 | katsuura
# Processing Record 31 of Set 5 | sao joao da barra
# Processing Record 32 of Set 5 | panama city
# Processing Record 33 of Set 5 | mato verde
# Processing Record 34 of Set 5 | kaniama
# Processing Record 35 of Set 5 | pierre
# Processing Record 36 of Set 5 | carutapera
# Processing Record 37 of Set 5 | abu samrah
# Processing Record 38 of Set 5 | ripon
# Processing Record 39 of Set 5 | dwarka
# Processing Record 40 of Set 5 | margate
# Processing Record 41 of Set 5 | vredendal
# Processing Record 42 of Set 5 | leiyang
# Processing Record 43 of Set 5 | minsk
# Processing Record 44 of Set 5 | izumo
# Processing Record 45 of Set 5 | abha
# Processing Record 46 of Set 5 | saint george
# Processing Record 47 of Set 5 | statesboro
# Processing Record 48 of Set 5 | tessalit
# Processing Record 49 of Set 5 | phan thiet
# Processing Record 50 of Set 5 | wazzan
# City not found. Skipping...
# Processing Record 1 of Set 6 | hovd
# Processing Record 2 of Set 6 | togur
# Processing Record 3 of Set 6 | ancud
# Processing Record 4 of Set 6 | korla
# Processing Record 5 of Set 6 | xudat
# Processing Record 6 of Set 6 | te anau
# Processing Record 7 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 6 | quiruvilca
# Processing Record 9 of Set 6 | brae
# Processing Record 10 of Set 6 | springdale
# Processing Record 11 of Set 6 | karlskrona
# Processing Record 12 of Set 6 | caluquembe
# Processing Record 13 of Set 6 | taksimo
# Processing Record 14 of Set 6 | tonj
# Processing Record 15 of Set 6 | samarai
# Processing Record 16 of Set 6 | marshall
# Processing Record 17 of Set 6 | torbay
# Processing Record 18 of Set 6 | faanui
# Processing Record 19 of Set 6 | huarmey
# Processing Record 20 of Set 6 | impfondo
# Processing Record 21 of Set 6 | borogontsy
# Processing Record 22 of Set 6 | joshimath
# Processing Record 23 of Set 6 | lewistown
# Processing Record 24 of Set 6 | karratha
# Processing Record 25 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 6 | buraydah
# Processing Record 27 of Set 6 | umm lajj
# Processing Record 28 of Set 6 | spearfish
# Processing Record 29 of Set 6 | mount gambier
# Processing Record 30 of Set 6 | kaeo
# Processing Record 31 of Set 6 | nipawin
# Processing Record 32 of Set 6 | yanagawa
# Processing Record 33 of Set 6 | hobyo
# Processing Record 34 of Set 6 | severnyy
# Processing Record 35 of Set 6 | chapais
# Processing Record 36 of Set 6 | itoman
# Processing Record 37 of Set 6 | minab
# Processing Record 38 of Set 6 | mengyin
# Processing Record 39 of Set 6 | houma
# Processing Record 40 of Set 6 | mitu
# Processing Record 41 of Set 6 | caruray
# Processing Record 42 of Set 6 | leh
# Processing Record 43 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 44 of Set 6 | wattens
# Processing Record 45 of Set 6 | galesong
# Processing Record 46 of Set 6 | swan river
# Processing Record 47 of Set 6 | rantepao
# Processing Record 48 of Set 6 | harper
# Processing Record 49 of Set 6 | qaqortoq
# Processing Record 50 of Set 6 | usinsk
# Processing Record 1 of Set 7 | hofn
# Processing Record 2 of Set 7 | pokaran
# Processing Record 3 of Set 7 | peniche
# Processing Record 4 of Set 7 | fukue
# Processing Record 5 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 6 of Set 7 | haines junction
# Processing Record 7 of Set 7 | lorengau
# Processing Record 8 of Set 7 | udachnyy
# Processing Record 9 of Set 7 | bilma
# Processing Record 10 of Set 7 | takestan
# Processing Record 11 of Set 7 | comodoro rivadavia
# Processing Record 12 of Set 7 | ayan
# Processing Record 13 of Set 7 | chernyshevskiy
# Processing Record 14 of Set 7 | grindavik
# Processing Record 15 of Set 7 | vohibinany
# Processing Record 16 of Set 7 | codrington
# Processing Record 17 of Set 7 | labuhan
# Processing Record 18 of Set 7 | fairbanks
# Processing Record 19 of Set 7 | manta
# Processing Record 20 of Set 7 | omsukchan
# Processing Record 21 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 7 | vetluga
# Processing Record 23 of Set 7 | general roca
# Processing Record 24 of Set 7 | belyy yar
# Processing Record 25 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 26 of Set 7 | shunyi
# Processing Record 27 of Set 7 | goderich
# Processing Record 28 of Set 7 | thinadhoo
# Processing Record 29 of Set 7 | nurota
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 7 | leningradskiy
# Processing Record 32 of Set 7 | medea
# Processing Record 33 of Set 7 | lagoa
# Processing Record 34 of Set 7 | bima
# Processing Record 35 of Set 7 | yefimovskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | quatre cocos
# Processing Record 37 of Set 7 | srednekolymsk
# Processing Record 38 of Set 7 | ribeira grande
# Processing Record 39 of Set 7 | phultala
# Processing Record 40 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 7 | charlestown
# Processing Record 42 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 7 | tezu
# Processing Record 44 of Set 7 | aviles
# Processing Record 45 of Set 7 | sunrise manor
# Processing Record 46 of Set 7 | aksu
# Processing Record 47 of Set 7 | bambous virieux
# Processing Record 48 of Set 7 | coquimbo
# Processing Record 49 of Set 7 | praia da vitoria
# Processing Record 50 of Set 7 | nanortalik
# Processing Record 1 of Set 8 | boende
# Processing Record 2 of Set 8 | batticaloa
# Processing Record 3 of Set 8 | asosa
# Processing Record 4 of Set 8 | surman
# Processing Record 5 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 6 of Set 8 | lesogorsk
# Processing Record 7 of Set 8 | dandong
# Processing Record 8 of Set 8 | gamba
# Processing Record 9 of Set 8 | namie
# Processing Record 10 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 8 | fort smith
# Processing Record 12 of Set 8 | port macquarie
# Processing Record 13 of Set 8 | san pedro
# Processing Record 14 of Set 8 | cidreira
# Processing Record 15 of Set 8 | mabaruma
# Processing Record 16 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 8 | vao
# Processing Record 18 of Set 8 | barra patuca
# Processing Record 19 of Set 8 | djambala
# Processing Record 20 of Set 8 | alofi
# Processing Record 21 of Set 8 | panjakent
# Processing Record 22 of Set 8 | marsa matruh
# Processing Record 23 of Set 8 | mecca
# Processing Record 24 of Set 8 | luderitz
# Processing Record 25 of Set 8 | dingle
# Processing Record 26 of Set 8 | urumqi
# Processing Record 27 of Set 8 | husavik
# Processing Record 28 of Set 8 | adjumani
# Processing Record 29 of Set 8 | natal
# Processing Record 30 of Set 8 | beyneu
# Processing Record 31 of Set 8 | bulancak
# Processing Record 32 of Set 8 | aitape
# Processing Record 33 of Set 8 | port hedland
# Processing Record 34 of Set 8 | pacific grove
# Processing Record 35 of Set 8 | tiznit
# Processing Record 36 of Set 8 | canico
# Processing Record 37 of Set 8 | valparaiso
# Processing Record 38 of Set 8 | arona
# Processing Record 39 of Set 8 | vila franca do campo
# Processing Record 40 of Set 8 | touros
# Processing Record 41 of Set 8 | mountain home
# Processing Record 42 of Set 8 | daliao
# Processing Record 43 of Set 8 | kununurra
# Processing Record 44 of Set 8 | acopiara
# Processing Record 45 of Set 8 | cairns
# Processing Record 46 of Set 8 | suihua
# Processing Record 47 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 8 | hermiston
# Processing Record 49 of Set 8 | itigi
# Processing Record 50 of Set 8 | buala
# Processing Record 1 of Set 9 | qabis
# City not found. Skipping...
# Processing Record 2 of Set 9 | akdepe
# Processing Record 3 of Set 9 | azul
# Processing Record 4 of Set 9 | torrington
# Processing Record 5 of Set 9 | shelton
# Processing Record 6 of Set 9 | calabozo
# Processing Record 7 of Set 9 | sambava
# Processing Record 8 of Set 9 | zyryanka
# Processing Record 9 of Set 9 | pisco
# Processing Record 10 of Set 9 | tevaitoa
# Processing Record 11 of Set 9 | bani walid
# Processing Record 12 of Set 9 | maarianhamina
# Processing Record 13 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 14 of Set 9 | la sarre
# Processing Record 15 of Set 9 | ouahigouya
# Processing Record 16 of Set 9 | ladario
# Processing Record 17 of Set 9 | filingue
# Processing Record 18 of Set 9 | yar-sale
# Processing Record 19 of Set 9 | virginia beach
# Processing Record 20 of Set 9 | mulege
# Processing Record 21 of Set 9 | camopi
# Processing Record 22 of Set 9 | itaituba
# Processing Record 23 of Set 9 | dezful
# Processing Record 24 of Set 9 | aykhal
# Processing Record 25 of Set 9 | rancho palos verdes
# Processing Record 26 of Set 9 | kudahuvadhoo
# Processing Record 27 of Set 9 | luanda
# Processing Record 28 of Set 9 | konevo
# Processing Record 29 of Set 9 | ilulissat
# Processing Record 30 of Set 9 | krasnoarmeysk
# Processing Record 31 of Set 9 | boa vista
# Processing Record 32 of Set 9 | chino valley
# Processing Record 33 of Set 9 | hay river
# Processing Record 34 of Set 9 | san luis
# Processing Record 35 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 9 | khani
# Processing Record 37 of Set 9 | kismayo
# Processing Record 38 of Set 9 | sigmaringen
# Processing Record 39 of Set 9 | vrangel
# Processing Record 40 of Set 9 | manokwari
# Processing Record 41 of Set 9 | bonga
# Processing Record 42 of Set 9 | shache
# Processing Record 43 of Set 9 | elat
# Processing Record 44 of Set 9 | lubango
# Processing Record 45 of Set 9 | natchitoches
# Processing Record 46 of Set 9 | iracoubo
# Processing Record 47 of Set 9 | sao jose da coroa grande
# Processing Record 48 of Set 9 | palmer
# Processing Record 49 of Set 9 | salinopolis
# Processing Record 50 of Set 9 | val
# Processing Record 1 of Set 10 | amot
# Processing Record 2 of Set 10 | alyangula
# Processing Record 3 of Set 10 | chimbote
# Processing Record 4 of Set 10 | uzhur-4
# City not found. Skipping...
# Processing Record 5 of Set 10 | pombia
# Processing Record 6 of Set 10 | presidente medici
# Processing Record 7 of Set 10 | tabuk
# Processing Record 8 of Set 10 | chicama
# Processing Record 9 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 10 of Set 10 | lahij
# Processing Record 11 of Set 10 | nadym
# Processing Record 12 of Set 10 | mattru
# Processing Record 13 of Set 10 | pasni
# Processing Record 14 of Set 10 | acarau
# Processing Record 15 of Set 10 | nanakuli
# Processing Record 16 of Set 10 | riposto
# Processing Record 17 of Set 10 | cagsiay
# Processing Record 18 of Set 10 | djibo
# Processing Record 19 of Set 10 | bereda
# Processing Record 20 of Set 10 | maxixe
# Processing Record 21 of Set 10 | portland
# Processing Record 22 of Set 10 | gambela
# Processing Record 23 of Set 10 | terney
# Processing Record 24 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 10 | tanout
# Processing Record 26 of Set 10 | provideniya
# Processing Record 27 of Set 10 | port lincoln
# Processing Record 28 of Set 10 | olafsvik
# Processing Record 29 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 10 | santa lucia
# Processing Record 31 of Set 10 | port blair
# Processing Record 32 of Set 10 | miri
# Processing Record 33 of Set 10 | sur
# Processing Record 34 of Set 10 | kasongo
# Processing Record 35 of Set 10 | ulladulla
# Processing Record 36 of Set 10 | elmira
# Processing Record 37 of Set 10 | griffith
# Processing Record 38 of Set 10 | petrozavodsk
# Processing Record 39 of Set 10 | susangerd
# Processing Record 40 of Set 10 | vanderhoof
# Processing Record 41 of Set 10 | bridlington
# Processing Record 42 of Set 10 | port hardy
# Processing Record 43 of Set 10 | aljezur
# Processing Record 44 of Set 10 | rockport
# Processing Record 45 of Set 10 | pangody
# Processing Record 46 of Set 10 | marysville
# Processing Record 47 of Set 10 | baykit
# Processing Record 48 of Set 10 | qasigiannguit
# Processing Record 49 of Set 10 | topolobampo
# Processing Record 50 of Set 10 | rosetown
# Processing Record 1 of Set 11 | bontang
# Processing Record 2 of Set 11 | gizo
# Processing Record 3 of Set 11 | myitkyina
# Processing Record 4 of Set 11 | brigantine
# Processing Record 5 of Set 11 | fort-shevchenko
# Processing Record 6 of Set 11 | gorontalo
# Processing Record 7 of Set 11 | jaciara
# Processing Record 8 of Set 11 | mayo
# Processing Record 9 of Set 11 | komsomolskiy
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | hue
# Processing Record 12 of Set 11 | katherine
# Processing Record 13 of Set 11 | kembe
# Processing Record 14 of Set 11 | de aar
# Processing Record 15 of Set 11 | gannan
# Processing Record 16 of Set 11 | butembo
# Processing Record 17 of Set 11 | korem
# Processing Record 18 of Set 11 | merauke
# Processing Record 19 of Set 11 | masumbwe
# Processing Record 20 of Set 11 | saint anthony
# Processing Record 21 of Set 11 | aklavik
# Processing Record 22 of Set 11 | arica
# Processing Record 23 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 11 | north bend
# Processing Record 25 of Set 11 | kota tinggi
# Processing Record 26 of Set 11 | salinas
# Processing Record 27 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 28 of Set 11 | emerald
# Processing Record 29 of Set 11 | yeniseysk
# Processing Record 30 of Set 11 | kushima
# Processing Record 31 of Set 11 | marzuq
# Processing Record 32 of Set 11 | springbok
# Processing Record 33 of Set 11 | concepcion del oro
# Processing Record 34 of Set 11 | vung tau
# Processing Record 35 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 11 | neiafu
# Processing Record 37 of Set 11 | russell
# Processing Record 38 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 11 | makakilo city
# Processing Record 40 of Set 11 | galveston
# Processing Record 41 of Set 11 | batagay-alyta
# Processing Record 42 of Set 11 | canutama
# Processing Record 43 of Set 11 | beloha
# Processing Record 44 of Set 11 | namibe
# Processing Record 45 of Set 11 | taltal
# Processing Record 46 of Set 11 | itarema
# Processing Record 47 of Set 11 | el alto
# Processing Record 48 of Set 11 | marawi
# Processing Record 49 of Set 11 | balad
# Processing Record 50 of Set 11 | saldanha
# Processing Record 1 of Set 12 | opuwo
# Processing Record 2 of Set 12 | iqaluit
# Processing Record 3 of Set 12 | siocon
# Processing Record 4 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 12 | cabedelo
# Processing Record 6 of Set 12 | puerto baquerizo moreno
# Processing Record 7 of Set 12 | dovbysh
# Processing Record 8 of Set 12 | ouadda
# Processing Record 9 of Set 12 | zhoucheng
# Processing Record 10 of Set 12 | manzhouli
# Processing Record 11 of Set 12 | bandarbeyla
# Processing Record 12 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 12 | oxilithos
# Processing Record 14 of Set 12 | arman
# Processing Record 15 of Set 12 | qiongshan
# Processing Record 16 of Set 12 | abbeville
# Processing Record 17 of Set 12 | prainha
# Processing Record 18 of Set 12 | lompoc
# Processing Record 19 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 12 | teknaf
# Processing Record 21 of Set 12 | dustlik
# Processing Record 22 of Set 12 | nome
# Processing Record 23 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 12 | chandrakona
# Processing Record 25 of Set 12 | lethem
# Processing Record 26 of Set 12 | albanel
# Processing Record 27 of Set 12 | ponferrada
# Processing Record 28 of Set 12 | serenje
# Processing Record 29 of Set 12 | richards bay
# Processing Record 30 of Set 12 | tholos
# Processing Record 31 of Set 12 | pabna
# Processing Record 32 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 12 | pitimbu
# Processing Record 34 of Set 12 | linxia
# Processing Record 35 of Set 12 | kokopo
# Processing Record 36 of Set 12 | cururupu
# Processing Record 37 of Set 12 | dong hoi
# Processing Record 38 of Set 12 | saint-pierre
# Processing Record 39 of Set 12 | antofagasta
# Processing Record 40 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 12 | cayenne
# Processing Record 42 of Set 12 | lazaro cardenas
# Processing Record 43 of Set 12 | kouroussa
# Processing Record 44 of Set 12 | canavieiras
# Processing Record 45 of Set 12 | aksarka
# Processing Record 46 of Set 12 | vardo
# Processing Record 47 of Set 12 | fukumitsu
# Processing Record 48 of Set 12 | sidney
# Processing Record 49 of Set 12 | deputatskiy
# Processing Record 50 of Set 12 | diego de almagro
# Processing Record 1 of Set 13 | ambilobe
# Processing Record 2 of Set 13 | verkhniye kigi
# Processing Record 3 of Set 13 | northam
# Processing Record 4 of Set 13 | iralaya
# Processing Record 5 of Set 13 | polunochnoye
# Processing Record 6 of Set 13 | kemin
# Processing Record 7 of Set 13 | kalmunai
# Processing Record 8 of Set 13 | lagos
# Processing Record 9 of Set 13 | aripuana
# Processing Record 10 of Set 13 | ketchikan
# Processing Record 11 of Set 13 | erseke
# Processing Record 12 of Set 13 | roebourne
# Processing Record 13 of Set 13 | sooke
# Processing Record 14 of Set 13 | vila velha
# Processing Record 15 of Set 13 | plaridel
# Processing Record 16 of Set 13 | katobu
# Processing Record 17 of Set 13 | languyan
# Processing Record 18 of Set 13 | poum
# Processing Record 19 of Set 13 | nishihara
# Processing Record 20 of Set 13 | agadez
# Processing Record 21 of Set 13 | namtsy
# Processing Record 22 of Set 13 | palafrugell
# Processing Record 23 of Set 13 | taoudenni
# Processing Record 24 of Set 13 | langres
# Processing Record 25 of Set 13 | hailey
# Processing Record 26 of Set 13 | chany
# Processing Record 27 of Set 13 | clovis
# Processing Record 28 of Set 13 | qostanay
# Processing Record 29 of Set 13 | zuwarah
# Processing Record 30 of Set 13 | baherden
# Processing Record 31 of Set 13 | prokopyevsk
# Processing Record 32 of Set 13 | shubarshi
# Processing Record 33 of Set 13 | shakiso
# Processing Record 34 of Set 13 | blairmore
# Processing Record 35 of Set 13 | bedford
# Processing Record 36 of Set 13 | madimba
# Processing Record 37 of Set 13 | alihe
# Processing Record 38 of Set 13 | monte azul
# Processing Record 39 of Set 13 | phon
# Processing Record 40 of Set 13 | rawson
# Processing Record 41 of Set 13 | saint albans
# Processing Record 42 of Set 13 | okha
# Processing Record 43 of Set 13 | binzhou
# Processing Record 44 of Set 13 | pauini
# Processing Record 45 of Set 13 | harij
# Processing Record 46 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 13 | guiyang
# Processing Record 48 of Set 13 | padang
# Processing Record 49 of Set 13 | oistins
# Processing Record 50 of Set 13 | san ignacio
# Processing Record 1 of Set 14 | bukachacha
# Processing Record 2 of Set 14 | hamilton
# Processing Record 3 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 4 of Set 14 | dickinson
# Processing Record 5 of Set 14 | ixtapa
# Processing Record 6 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 14 | charters towers
# Processing Record 8 of Set 14 | new deer
# Processing Record 9 of Set 14 | sistranda
# Processing Record 10 of Set 14 | la libertad
# Processing Record 11 of Set 14 | baruun-urt
# Processing Record 12 of Set 14 | kieta
# Processing Record 13 of Set 14 | dembi dolo
# Processing Record 14 of Set 14 | nelson bay
# Processing Record 15 of Set 14 | san andres
# Processing Record 16 of Set 14 | cravo norte
# Processing Record 17 of Set 14 | yegorlykskaya
# Processing Record 18 of Set 14 | obo
# Processing Record 19 of Set 14 | plouzane
# Processing Record 20 of Set 14 | sola
# Processing Record 21 of Set 14 | sobolevo
# Processing Record 22 of Set 14 | hlubocky
# Processing Record 23 of Set 14 | caravelas
# Processing Record 24 of Set 14 | cascais
# Processing Record 25 of Set 14 | usagara
# Processing Record 26 of Set 14 | jatiroto
# Processing Record 27 of Set 14 | urdoma
# Processing Record 28 of Set 14 | mersing
# Processing Record 29 of Set 14 | ucluelet
# Processing Record 30 of Set 14 | almaznyy
# Processing Record 31 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 14 | south venice
# Processing Record 33 of Set 14 | nicolas bravo
# Processing Record 34 of Set 14 | baghdad
# Processing Record 35 of Set 14 | tiarei
# Processing Record 36 of Set 14 | porto santo
# Processing Record 37 of Set 14 | hanna
# Processing Record 38 of Set 14 | wahiawa
# Processing Record 39 of Set 14 | ardeoani
# Processing Record 40 of Set 14 | hualmay
# Processing Record 41 of Set 14 | aquiraz
# Processing Record 42 of Set 14 | abu zabad
# Processing Record 43 of Set 14 | umm kaddadah
# Processing Record 44 of Set 14 | biggar
# Processing Record 45 of Set 14 | matara
# Processing Record 46 of Set 14 | port-gentil
# Processing Record 47 of Set 14 | kucevo
# Processing Record 48 of Set 14 | egvekinot
# Processing Record 49 of Set 14 | okhotsk
# Processing Record 50 of Set 14 | kysyl-syr
# Processing Record 1 of Set 15 | moron
# Processing Record 2 of Set 15 | saquena
# Processing Record 3 of Set 15 | coolum beach
# Processing Record 4 of Set 15 | lichinga
# Processing Record 5 of Set 15 | manoel urbano
# Processing Record 6 of Set 15 | flin flon
# Processing Record 7 of Set 15 | zermatt
# Processing Record 8 of Set 15 | arroio dos ratos
# Processing Record 9 of Set 15 | seydi
# Processing Record 10 of Set 15 | ahmadpur
# Processing Record 11 of Set 15 | albert town
# Processing Record 12 of Set 15 | teguldet
# Processing Record 13 of Set 15 | port keats
# Processing Record 14 of Set 15 | auki
# Processing Record 15 of Set 15 | uruzgan
# Processing Record 16 of Set 15 | moussoro
# Processing Record 17 of Set 15 | moche
# Processing Record 18 of Set 15 | yanam
# Processing Record 19 of Set 15 | isangel
# Processing Record 20 of Set 15 | swellendam
# Processing Record 21 of Set 15 | albury
# Processing Record 22 of Set 15 | lipin bor
# Processing Record 23 of Set 15 | ihosy
# Processing Record 24 of Set 15 | gumdag
# Processing Record 25 of Set 15 | loikaw
# Processing Record 26 of Set 15 | inirida
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 0               San Cristobal   7.7669  -72.2250     86.00        66
# 1                 San Quintin  30.4833 -115.9500     65.50        62
# 2                     Qaanaaq  77.4840  -69.3632     32.54        92
# 3                     Rikitea -23.1203 -134.9692     75.04        75
# 4                Vila Do Maio  15.1333  -23.2167     79.59        84
# 5                Punta Arenas -53.1500  -70.9167     37.51        56
# 6                     Sorland  67.6670   12.6934     46.40        93
# 7                      Bethel  41.3712  -73.4140     48.00        95
# 8                San Patricio  28.0170  -97.5169     89.69        56
# 9                      Eureka  40.8021 -124.1637     61.00        77
# 10                  Busselton -33.6500  115.3333     55.09        65
# 11                     Atuona  -9.8000 -139.0333     79.95        61
# 12                Tuktoyaktuk  69.4541 -133.0374     39.20        56
# 13                   Hermanus -34.4187   19.2345     56.89        80
# 14                   Flinders -34.5833  150.8552     54.21        82
# 15                      Kapaa  22.0752 -159.3190     79.20        71
# 16                     Khilok  51.3674  110.4676     29.55        72
# 17  Petropavlovsk-Kamchatskiy  53.0452  158.6483     37.99        87
# 18                    Bubaque  11.2833  -15.8333     78.06        75
# 19                  Karpogory  64.0019   44.4451     36.72        65
#
#     Cloudiness  Wind Speed Country Current Description
# 0           40       11.50      VE    scattered clouds
# 1           40       15.14      MX    scattered clouds
# 2          100        5.50      GL     overcast clouds
# 3           94       12.88      PF          light rain
# 4           85       18.54      CV     overcast clouds
# 5           75        9.42      CL       broken clouds
# 6           75       12.66      NO       broken clouds
# 7          100        1.01      US          light rain
# 8           18       14.99      US          few clouds
# 9          100        5.01      US     overcast clouds
# 10         100       14.94      AU     overcast clouds
# 11           2        8.01      PF           clear sky
# 12          20       11.50      CA          few clouds
# 13          93        5.61      ZA     overcast clouds
# 14           0        1.01      AU           clear sky
# 15           1        1.01      US           clear sky
# 16           3        3.18      RU           clear sky
# 17          75        3.65      RU       broken clouds
# 18          30       15.08      GW    scattered clouds
# 19          16        4.16      RU          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
